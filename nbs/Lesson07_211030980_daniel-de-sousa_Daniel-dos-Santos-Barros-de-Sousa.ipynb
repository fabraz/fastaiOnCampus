# %% [markdown]
# # Artigo 7 - Blog Recommendation

# %% [markdown]
# ## Objetivo
# Para esse artigo, o objetivo é colocar em prática só conhecimentos da lição 7, que se trata de Filtros Colaborativos, disponível em duas partes: [Parte 1](https://course.fast.ai/Lessons/lesson7.html) (do meio para o final) e [Parte 2](https://course.fast.ai/Lessons/lesson8.html) (do início para o meio). Nesse caso o objetivo é mediante a dados tabulares, entender o comportamento de usuários e através disso perceber quais seriam as melhores recomendações para esse usuário. Sendo que para esse caso específico se deseja fazer recomendações de blogs que interessem os usuários, sendo para isso usado os dados presentes no [Blog Recommendation Data](https://www.kaggle.com/datasets/yakshshah/blog-recommendation-data/data). Além de que no final, o resultado será exporto em forma de um modelo disponibilizado no Hugging Face.

# %% [markdown]
# ## Motivação
# O habito de leitura é imprescindível para o crescimento intelectual das pessoas, e esse hábito se torna mais prazeroso quando a pessoa se depara com conteúdos de seu interesse, por isso, ter um modelo que seja capaz de se fazer essa recomendação ajudará com que a pessoa consiga estar diante de conteúdos que goste e possa continuar sua leitura de maneira prazerosa.

# %% [markdown]
# ## Requisitos
# Para se realizar essa tarefa é necessário ter algumas bibliotecas que servirão para poder fazer toda a manipulação dos dados e até mesmo para a criação do modelo, todas elas podem ser encontradas na célula 01.

# %%
from fastai.collab import *      #Collab para fazer filtros colaborativos usando fastai
from fastai.tabular.all import * #Tabular para poder mexer com os dados Tabulares

from pathlib import Path #Path para manipular pastas

import numpy as np  #Numby para cálculos
import pandas as pd #Pandas para fazer e manipular DataFrames

set_seed(42) #Seed para poder replicar esse notebook
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# Outra coisa necessária são os dados, para isso, foi feito o download deles na base de dados [Blog Recommendation Data](https://www.kaggle.com/datasets/yakshshah/blog-recommendation-data/data) e colocado no input para poder ser usado, esses passos podem ser observandos ná célula 02.

# %%
base = Path('../input/data-blog')

author_blog = pd.read_csv(base/'Author_Data.csv')
rating_blog = pd.read_csv(base/'Blog_Ratings.csv')
conten_blog = pd.read_csv(base/'Medium_Blog_Data.csv')

# %% [markdown]
# Esses dados estão distribuídos da seguinte maneira:
# * 0,5 - Se o usuário acabou de ler o blog
# * 2 - Se o usuário gostou do blog
# * 3,5 - Se o usuário adicionou o blog aos favoritos
# * 5 - Se o usuário gostou e adicionou o blog para favoritos

# %% [markdown]
# ## Dados
# Agora, com os dados devidamente lidos, uma primeira coisa a se fazer é visualizar eles para uma primeira análise e entender como estão dispostas as informações e se saber o que se deseja usar de cada um, esse processo pode ser observado nas célula 03 a 05.

# %%
author_blog
# Out:
#       author_id             author_name
# 0             1                   yaksh
# 1             2                     XIT
# 2             3            Daniel Meyer
# 3             4            Seedify Fund
# 4             5  Ifedolapo Shiloh Olotu
# ...         ...                     ...
# 6863       6864    Fresh Frontend Links
# 6864       6865           Mukesh buwade
# 6865       6866              Osei Owusu
# 6866       6867          Yasas Sandeepa
# 6867       6868       Aphinya Dechalert
#
# [6868 rows x 2 columns]

# %%
rating_blog
# Out:
#         blog_id  userId  ratings
# 0          9025      11      3.5
# 1          9320      11      5.0
# 2          9246      11      3.5
# 3          9431      11      5.0
# 4           875      11      2.0
# ...         ...     ...      ...
# 200135     6714      22      5.0
# 200136     6576      22      3.5
# 200137     6222      22      3.5
# 200138     6015      22      2.0
# 200139     7842      22      2.0
#
# [200140 rows x 3 columns]

# %%
conten_blog
# Out:
#        blog_id  author_id  \
# 0            1          4
# 1            3          4
# 2            4          7
# 3            5          8
# 4            6          9
# ...        ...        ...
# 10462    10489       6867
# 10463    10490       2490
# 10464    10491       6810
# 10465    10492       6868
# 10466    10493       6750
#
#                                                                                                  blog_title  \
# 0                                                                  Let’s Dominate The Launchpad Space Again
# 1                                                                  Let’s Dominate The Launchpad Space Again
# 2                                                                           Using ChatGPT for User Research
# 3                                                The Automated Stable-Diffusion Checkpoint Merger, autoMBW.
# 4                  The Art of Lazy Creativity: My Experience Co-Writing a Monty Python Style Sketch with AI
# ...                                                                                                     ...
# 10462                                                   Introducing Qwik — A Superfast JavaScript Framework
# 10463                            A Beginner’s Guide to Cypress Testing Framework with a Weather Application
# 10464                                                                      How To Use Awaited in TypeScript
# 10465                                                  Angular Hydration? WTF is it and why does it matter?
# 10466  How to easily build a website with VILT (Vue Inertia Laravel Tailwind) Stack — Part 1 (Installation)
#
#                                                                                                                                                                                                                                                                                                                                                                                  blog_content  \
# 0                                                                         Hello, fam! If you’ve been with us since 2021, you probably remember our first announcements regarding the strategies to dominate the launchpad space in the previous bull. To recall it once more, it was (1) first upgrading our launchpad tier system and then (2) going full-deep into blockchain gaming while…
# 1                                                                         Hello, fam! If you’ve been with us since 2021, you probably remember our first announcements regarding the strategies to dominate the launchpad space in the previous bull. To recall it once more, it was (1) first upgrading our launchpad tier system and then (2) going full-deep into blockchain gaming while…
# 2                               Applying AI to 4 common user research activities —  User research is a fundamental part of the design process. The more time and energy a product team invests in user research, the higher the chances of releasing a commercially successful product. In this article, I will explore whether ChatGPT can be helpful for user and market research. To make…
# 3                      Checkpoint merging is powerful. The power of checkpoint merging is undeniable. With the introduction of bbc-mc’s sdweb-merge-block-weighted-gui extension, the potential for checkpoint merging has increased exponentially in comparison to older methods. In fact, this method is so powerful that most of all modern merged models incorporate MBW merges in their…
# 4                                                                                                                   I was feeling particularly lazy one day and couldn’t be bothered to write anything. So, I turned to ChatGPT, the AI language model, to help me out. But even that was too much effort, so I asked ChatGPT to write this article too. And boy, did it deliver! So, here’s…
# ...                                                                                                                                                                                                                                                                                                                                                                                       ...
# 10462                               An overview of Qwik’s key features and architecture —  As you may be aware, numerous JavaScript frameworks have emerged rapidly in the past few years. But this one brings an entirely new rendering paradigm to the table. It’s none other than Qwik. Qwik is as it sounds, super quick. It claims the fastest front-end framework right now. It offers…
# 10463                                                             Cypress is a popular JavaScript testing framework for end-to-end testing of web applications. If you have some experience with unit testing using React Testing Library, you may wonder how to test your app’s interaction with the browser in a real-world scenario. Cypress provides a solution by allowing you to write…
# 10464  Unraveling the magic of Promise handling with TypeScript’s Awaited utility type —  Hello there, fellow TypeScript savants! 🎩🐇 In this article, we’re going to unpack the Awaited utility type introduced in TypeScript 4.5. As the name suggests, Awaited helps us handle Promises in TypeScript, specifically mimicking the await keyword’s ability to recursively unwrap Promises. …
# 10465         How thirsty is your app for better performance? —  Angular hydration. At some point, someone might have mentioned it to you in your journey down the long windy road of Angular mastery. In a nutshell, this process restores a server-side rendered application on the client, and improves performance by avoiding extra work to re-create DOM nodes. However, while Angular…
# 10466                                                 Laravel is a web application framework with expressive, elegant syntax. A web framework provides a structure and starting point for creating your application, allowing you to focus on creating something amazing while we sweat the details. (Laravel.com) With Laravel we can make a website easily and quickly because of embedded…
#
#                                                                                                                                                                                                                                       blog_link  \
# 0                                                           https://medium.com/@seedifyfund/lets-dominate-the-launchpad-space-again-7155875002f3?source=topics_v2---------0-84--------------------99dddee2_0334_40c4_901c_47e0e6948b6c-------17
# 1                                                           https://medium.com/@seedifyfund/lets-dominate-the-launchpad-space-again-7155875002f3?source=topics_v2---------0-84--------------------99dddee2_0334_40c4_901c_47e0e6948b6c-------17
# 2                                                                      https://medium.com/ux-planet/using-chatgpt-for-user-research-5c3bdf7e26af?source=topics_v2---------1-84--------------------99dddee2_0334_40c4_901c_47e0e6948b6c-------17
# 3                                          https://medium.com/@media_97267/the-automated-stable-diffusion-checkpoint-merger-autombw-44f8dfd38871?source=topics_v2---------2-84--------------------99dddee2_0334_40c4_901c_47e0e6948b6c-------17
# 4      https://medium.com/@digitalshedmedia/the-art-of-lazy-creativity-my-experience-co-writing-a-monty-python-style-sketch-with-ai-869bf5ff6a06?source=topics_v2---------3-84--------------------99dddee2_0334_40c4_901c_47e0e6948b6c-------17
# ...                                                                                                                                                                                                                                         ...
# 10462                                           https://medium.com/gitconnected/introducing-qwik-a-superfast-javascript-framework-419509a0ca65?source=topics_v2---------204-84--------------------fe2372ea_0f34_4c17_ab3d_2c656faeda5c-------17
# 10463                         https://medium.com/itnext/a-beginners-guide-to-cypress-testing-framework-with-a-weather-application-88dbf6ddae6c?source=topics_v2---------205-84--------------------fe2372ea_0f34_4c17_ab3d_2c656faeda5c-------17
# 10464                                                      https://medium.com/totally-typescript/how-to-use-awaited-in-typescript-66c340dfa491?source=topics_v2---------206-84--------------------fe2372ea_0f34_4c17_ab3d_2c656faeda5c-------17
# 10465                                     https://medium.com/@PurpleGreenLemon/angular-hydration-wtf-is-it-and-why-does-it-matter-9152d55547c0?source=topics_v2---------207-84--------------------fe2372ea_0f34_4c17_ab3d_2c656faeda5c-------17
# 10466              https://medium.com/@miqbal20/how-to-easily-build-a-website-with-vilt-vue-inertia-laravel-tailwind-stack-part-1-19fcf3bbe1ad?source=topics_v2---------208-84--------------------fe2372ea_0f34_4c17_ab3d_2c656faeda5c-------17
#
#                                                                                blog_img  \
# 0                    https://miro.medium.com/fit/c/140/140/1*nByLJrDhJHndW_wRv4k3JA.png
# 1                    https://miro.medium.com/fit/c/140/140/1*nByLJrDhJHndW_wRv4k3JA.png
# 2                    https://miro.medium.com/fit/c/140/140/1*TZSGnNza4YgHJJ4yeKdVUw.png
# 3                    https://miro.medium.com/fit/c/140/140/1*x3N_Hjgu_MjFyc6-kyxUxw.png
# 4                              https://miro.medium.com/fit/c/140/140/0*m2DdeTvRYz8Cpor2
# ...                                                                                 ...
# 10462       https://miro.medium.com/v2/resize:fill:140:140/1*sb72ov-4tO7WTOwbzDipAA.png
# 10463                 https://miro.medium.com/v2/resize:fill:140:140/0*hKvrIS2z_K5Fk7U5
# 10464  https://miro.medium.com/v2/resize:fill:140:140/g:fp:0.45:0.54/0*RAPyHzu8Rc19f3m0
# 10465      https://miro.medium.com/v2/resize:fill:140:140/1*vm65O-xxgnz3zIhsB-gEQA.jpeg
# 10466             https://miro.medium.com/v2/resize:fill:140:140/0*PWZnUFiRCyMwHus4.png
#
#                  topic          scrape_time
# 0                   ai  2023-02-27 07:37:48
# 1                   ai  2023-02-27 07:41:47
# 2                   ai  2023-02-27 07:41:47
# 3                   ai  2023-02-27 07:41:47
# 4                   ai  2023-02-27 07:41:47
# ...                ...                  ...
# 10462  web-development  2023-05-08 10:36:42
# 10463  web-development  2023-05-08 10:36:42
# 10464  web-development  2023-05-08 10:36:42
# 10465  web-development  2023-05-08 10:36:42
# 10466  web-development  2023-05-08 10:36:42
#
# [10467 rows x 8 columns]

# %% [markdown]
# Como o intuito é fazer recomendações com base nas avaliações, entende-se que os DataFrames possuem algumas informações desnecessárias para poder criar e treinar o modelo que se deseja, sendo assim, a partir desses 3 DataFrames pode-se criar apenas 1 que possua os seguintes dados:
# * User: O ID de usuário
# * Blog: O ID do Blog
# * Rating: Nota dada ao Blog
# * Title: O título do Blog
#
# Isso já demostra um indicativo, que a parte de quem é o autor não é necessário, mas será mantido para quando for retornar o resultado, seja capaz de retorna um valor mais completo com o título do blog e seu autor.
#
# Esse processo de criar um DataFrame que contemple todos esses dados pode ser observado na célula 06.

# %%
blogs = rating_blog.copy()
blogs = blogs.merge(conten_blog.drop(['blog_content', 'blog_link', 'blog_img', 'topic', 'scrape_time'], axis=1))
blogs = blogs.merge(author_blog)

blogs
# Out:
#         blog_id  userId  ratings  author_id  \
# 0          9025      11      3.5       5960
# 1          9025      38      3.5       5960
# 2          9025     253      5.0       5960
# 3          9025     385      0.5       5960
# 4          9025     394      3.5       5960
# ...         ...     ...      ...        ...
# 200135     6741    4299      5.0       4659
# 200136     4459    3783      5.0       3256
# 200137     4459    4541      0.5       3256
# 200138     1353    4415      2.0       1094
# 200139     1353    4871      0.5       1094
#
#                                                       blog_title  \
# 0                              How I became a Frontend Developer
# 1                              How I became a Frontend Developer
# 2                              How I became a Frontend Developer
# 3                              How I became a Frontend Developer
# 4                              How I became a Frontend Developer
# ...                                                          ...
# 200135                          Data Science Interview Questions
# 200136               Catching Up with KaratDAO (Jan/Feb Updates)
# 200137               Catching Up with KaratDAO (Jan/Feb Updates)
# 200138  Can ChatGPT turn Negative Language into Positive Change?
# 200139  Can ChatGPT turn Negative Language into Positive Change?
#
#           author_name
# 0       Steven Dornan
# 1       Steven Dornan
# 2       Steven Dornan
# 3       Steven Dornan
# 4       Steven Dornan
# ...               ...
# 200135   Aman Kharwal
# 200136       KaratDAO
# 200137       KaratDAO
# 200138   Eduard Ruzga
# 200139   Eduard Ruzga
#
# [200140 rows x 6 columns]

# %% [markdown]
# Com isso se tem um DatFrame que possuem todos os dados necessários para criar e treinar o modelo e um pouco mais, porém, é verificado um problema, observável na célula 07.

# %%
blogs['ratings'].isnull().sum(), blogs['ratings'].isna().sum(), (blogs['ratings'] == 0).sum()
# Out:
# (0, 0, 0)

# %% [markdown]
# Isso demostra que todos os valores de avaliações estão preenchidos como valores diferentes de NaN(Not a Number), Null e 0. O que significa que não existem valores a serem preditos para poder fazer a recomendação, um dos motivos de isso ocorrer, é por que existem valores como 0,5, que indicam que o usuário fez a leitura do blog, mas isso não é uma informação útil no rating para fazer a predições, apenas valores acima desses são uteis, pois mostraram o quanto um usuário gostou de um blog, então para ter os campos que se deseja prever, esses valores serão colocados como 0, e a partir de agora indica que um usuário não deu nota para determinado blog, esse processo pode ser observado na célula 08.

# %%
blogs['ratings'] = blogs['ratings'].replace(0.5, 0)
blogs
# Out:
#         blog_id  userId  ratings  author_id  \
# 0          9025      11      3.5       5960
# 1          9025      38      3.5       5960
# 2          9025     253      5.0       5960
# 3          9025     385      0.0       5960
# 4          9025     394      3.5       5960
# ...         ...     ...      ...        ...
# 200135     6741    4299      5.0       4659
# 200136     4459    3783      5.0       3256
# 200137     4459    4541      0.0       3256
# 200138     1353    4415      2.0       1094
# 200139     1353    4871      0.0       1094
#
#                                                       blog_title  \
# 0                              How I became a Frontend Developer
# 1                              How I became a Frontend Developer
# 2                              How I became a Frontend Developer
# 3                              How I became a Frontend Developer
# 4                              How I became a Frontend Developer
# ...                                                          ...
# 200135                          Data Science Interview Questions
# 200136               Catching Up with KaratDAO (Jan/Feb Updates)
# 200137               Catching Up with KaratDAO (Jan/Feb Updates)
# 200138  Can ChatGPT turn Negative Language into Positive Change?
# 200139  Can ChatGPT turn Negative Language into Positive Change?
#
#           author_name
# 0       Steven Dornan
# 1       Steven Dornan
# 2       Steven Dornan
# 3       Steven Dornan
# 4       Steven Dornan
# ...               ...
# 200135   Aman Kharwal
# 200136       KaratDAO
# 200137       KaratDAO
# 200138   Eduard Ruzga
# 200139   Eduard Ruzga
#
# [200140 rows x 6 columns]

# %% [markdown]
# Agora o dado possui valores que vão poder ser preditos, porém, antes que isso possa ser realizado, é interessante verificar se não existe valores duplicados para alguns ids, esse processo pode ser visto na célula 09.

# %%
duplicates = blogs.duplicated(subset = ['userId', 'blog_id'], keep = False)
blogs[duplicates]
# Out:
#         blog_id  userId  ratings  author_id  \
# 8235       6295      13      3.5         63
# 8262       6295      13      2.0         63
# 57151      6680      22      0.0         74
# 57152      6680      22      5.0         74
# 67280      6714      22      0.0       4623
# 67281      6714      22      5.0       4623
# 74131      6576      22      0.0       1438
# 74132      6576      22      3.5       1438
# 74188      6504      22      0.0       1438
# 74189      6504      22      5.0       1438
# 74510      6552      22      0.0       1373
# 74511      6552      22      5.0       1373
# 83706      7085      22      0.0       1719
# 83707      7085      22      5.0       1719
# 85820      6142      22      0.0       4289
# 85821      6142      22      5.0       4289
# 123771     6015      22      0.0       4234
# 123772     6015      22      2.0       4234
# 163684     6222      22      0.0       4346
# 163685     6222      22      3.5       4346
# 177479     7921      22      0.0       5324
# 177480     7921      22      5.0       5324
# 185374     7842      22      0.0       5288
# 185375     7842      22      2.0       5288
#
#                                                                                      blog_title  \
# 8235                                                                  How to Run Your Own LLaMA
# 8262                                                                  How to Run Your Own LLaMA
# 57151                                                  Full Analysis with Interactive Dashboard
# 57152                                                  Full Analysis with Interactive Dashboard
# 67280                              Challenging Assumptions: Preparing for Unwanted Data Results
# 67281                              Challenging Assumptions: Preparing for Unwanted Data Results
# 74131                “Designing a Data Model for a Library Management System using PostgreSQL.”
# 74132                “Designing a Data Model for a Library Management System using PostgreSQL.”
# 74188                                  10 Ways to Improve Your SQL Queries: Tips and Techniques
# 74189                                  10 Ways to Improve Your SQL Queries: Tips and Techniques
# 74510    Connecting the Internet with ChatGPT (LLMs) using Langchain And Answers Your Questions
# 74511    Connecting the Internet with ChatGPT (LLMs) using Langchain And Answers Your Questions
# 83706   Deep learning in computer vision: Introduction, its applications, and future directions
# 83707   Deep learning in computer vision: Introduction, its applications, and future directions
# 85820                                                                OpenAI has become ClosedAI
# 85821                                                                OpenAI has become ClosedAI
# 123771                                                           Stanford-Alpaca: ChatGPT Rival
# 123772                                                           Stanford-Alpaca: ChatGPT Rival
# 163684                          Introduction to Natural Language Processing: A Beginner’s Guide
# 163685                          Introduction to Natural Language Processing: A Beginner’s Guide
# 177479     Leveling Up in Tech: My 3rd Teaching Experience and AWS DevOps Pro Exam Preparation.
# 177480     Leveling Up in Tech: My 3rd Teaching Experience and AWS DevOps Pro Exam Preparation.
# 185374                                                Run GitHub Actions in Your CI/CD Pipeline
# 185375                                                Run GitHub Actions in Your CI/CD Pipeline
#
#                          author_name
# 8235    Dr. Mandar Karhade, MD. PhD.
# 8262    Dr. Mandar Karhade, MD. PhD.
# 57151                     Amit Kumar
# 57152                     Amit Kumar
# 67280                Humberto Rendon
# 67281                Humberto Rendon
# 74131               Vishal Barvaliya
# 74132               Vishal Barvaliya
# 74188               Vishal Barvaliya
# 74189               Vishal Barvaliya
# 74510                   Qrious Kamal
# 74511                   Qrious Kamal
# 83706                    Saqib Qamar
# 83707                    Saqib Qamar
# 85820                     Alex Vaith
# 85821                     Alex Vaith
# 123771               Himanshu Sharma
# 123772               Himanshu Sharma
# 163684             Pol Guasch Romero
# 163685             Pol Guasch Romero
# 177479                 Jeffrey Ensor
# 177480                 Jeffrey Ensor
# 185374               Pavan Belagatti
# 185375               Pavan Belagatti

# %% [markdown]
# É possível observar que existem duplicatas, mas considerando as classificações, uma delas diz respeito se o usuário não deu nota a um blog e a outra a sua avaliação sobre eesse mesmo blogue, mas intrinsecamente, se ele avaliou o blog ele o leu, então é possível retirar as duplicatas onde a avaliação é 0. Isso pode ser observado na célula 10.

# %%
mask = (blogs.duplicated(subset = ['userId', 'blog_id'], keep = False)) & (blogs['ratings'] == 0.0)
blogs = blogs[~mask]

blogs
# Out:
#         blog_id  userId  ratings  author_id  \
# 0          9025      11      3.5       5960
# 1          9025      38      3.5       5960
# 2          9025     253      5.0       5960
# 3          9025     385      0.0       5960
# 4          9025     394      3.5       5960
# ...         ...     ...      ...        ...
# 200135     6741    4299      5.0       4659
# 200136     4459    3783      5.0       3256
# 200137     4459    4541      0.0       3256
# 200138     1353    4415      2.0       1094
# 200139     1353    4871      0.0       1094
#
#                                                       blog_title  \
# 0                              How I became a Frontend Developer
# 1                              How I became a Frontend Developer
# 2                              How I became a Frontend Developer
# 3                              How I became a Frontend Developer
# 4                              How I became a Frontend Developer
# ...                                                          ...
# 200135                          Data Science Interview Questions
# 200136               Catching Up with KaratDAO (Jan/Feb Updates)
# 200137               Catching Up with KaratDAO (Jan/Feb Updates)
# 200138  Can ChatGPT turn Negative Language into Positive Change?
# 200139  Can ChatGPT turn Negative Language into Positive Change?
#
#           author_name
# 0       Steven Dornan
# 1       Steven Dornan
# 2       Steven Dornan
# 3       Steven Dornan
# 4       Steven Dornan
# ...               ...
# 200135   Aman Kharwal
# 200136       KaratDAO
# 200137       KaratDAO
# 200138   Eduard Ruzga
# 200139   Eduard Ruzga
#
# [200129 rows x 6 columns]

# %% [markdown]
# Ainda existe uma linha duplicada, observada anteriormente, só que ela possui um rating de 2 e outro de 3.5, nesse caso, será mantido o maior rating, ela pode ser observada na célula 11.

# %%
index = blogs[(blogs['userId'] == 13) & (blogs['blog_id'] == 6295) & (blogs['ratings'] == 2.0)].index
blogs = blogs.drop(index)

blogs
# Out:
#         blog_id  userId  ratings  author_id  \
# 0          9025      11      3.5       5960
# 1          9025      38      3.5       5960
# 2          9025     253      5.0       5960
# 3          9025     385      0.0       5960
# 4          9025     394      3.5       5960
# ...         ...     ...      ...        ...
# 200135     6741    4299      5.0       4659
# 200136     4459    3783      5.0       3256
# 200137     4459    4541      0.0       3256
# 200138     1353    4415      2.0       1094
# 200139     1353    4871      0.0       1094
#
#                                                       blog_title  \
# 0                              How I became a Frontend Developer
# 1                              How I became a Frontend Developer
# 2                              How I became a Frontend Developer
# 3                              How I became a Frontend Developer
# 4                              How I became a Frontend Developer
# ...                                                          ...
# 200135                          Data Science Interview Questions
# 200136               Catching Up with KaratDAO (Jan/Feb Updates)
# 200137               Catching Up with KaratDAO (Jan/Feb Updates)
# 200138  Can ChatGPT turn Negative Language into Positive Change?
# 200139  Can ChatGPT turn Negative Language into Positive Change?
#
#           author_name
# 0       Steven Dornan
# 1       Steven Dornan
# 2       Steven Dornan
# 3       Steven Dornan
# 4       Steven Dornan
# ...               ...
# 200135   Aman Kharwal
# 200136       KaratDAO
# 200137       KaratDAO
# 200138   Eduard Ruzga
# 200139   Eduard Ruzga
#
# [200128 rows x 6 columns]

# %% [markdown]
# Apenas para uma melhor organização é interessante mexer nos nomes e em como eles aparecem, isso pode ser observado na célula 12.

# %%
blogs = blogs[['userId', 'blog_id', 'ratings', 'blog_title', 'author_id', 'author_name']]
blogs = blogs.rename(columns = {'userId': 'user', 'blog_id':'blog', 'ratings':'rating', 'blog_title':'title', 'author_id':'author', 'author_name':'name'})
blogs
# Out:
#         user  blog  rating  \
# 0         11  9025     3.5
# 1         38  9025     3.5
# 2        253  9025     5.0
# 3        385  9025     0.0
# 4        394  9025     3.5
# ...      ...   ...     ...
# 200135  4299  6741     5.0
# 200136  3783  4459     5.0
# 200137  4541  4459     0.0
# 200138  4415  1353     2.0
# 200139  4871  1353     0.0
#
#                                                            title  author  \
# 0                              How I became a Frontend Developer    5960
# 1                              How I became a Frontend Developer    5960
# 2                              How I became a Frontend Developer    5960
# 3                              How I became a Frontend Developer    5960
# 4                              How I became a Frontend Developer    5960
# ...                                                          ...     ...
# 200135                          Data Science Interview Questions    4659
# 200136               Catching Up with KaratDAO (Jan/Feb Updates)    3256
# 200137               Catching Up with KaratDAO (Jan/Feb Updates)    3256
# 200138  Can ChatGPT turn Negative Language into Positive Change?    1094
# 200139  Can ChatGPT turn Negative Language into Positive Change?    1094
#
#                  name
# 0       Steven Dornan
# 1       Steven Dornan
# 2       Steven Dornan
# 3       Steven Dornan
# 4       Steven Dornan
# ...               ...
# 200135   Aman Kharwal
# 200136       KaratDAO
# 200137       KaratDAO
# 200138   Eduard Ruzga
# 200139   Eduard Ruzga
#
# [200128 rows x 6 columns]

# %% [markdown]
# Apenas para uma questão de visualização melhor, é interessante representar esse DataFrame de outra maneira, observável na célula 13.

# %%
tabela = pd.pivot_table(blogs.iloc[:500], columns='user', values='rating', index='title', fill_value=0)
tabela
# Out:
# user                                                                                                  11    \
# title
# 2 ChatGPT (Free) Chrome Extensions so Useful They Almost Feel Illegal                                  0.0
# 51 Far Better Things to Do than Scrolling Through Your Smartphone                                      0.0
# Animated Icons: Bottom Nav in Flutter & Rive                                                           0.0
# April 1st Recommendation on Alignment                                                                  0.0
# Background Services in Flutter Add-to-App Case                                                         0.0
# Calling in the background in a flutter                                                                 0.0
# Chat-GPT: 5 Game-Changing Functions in AI, Content, Translation, Classification, and Personalization   0.0
# Conflux Network: A High-Throughput Proof-of-Work Blockchain                                            0.0
# Cryptocurrency Regulations: A Tug of War Between Investors and Bureaucrats                             2.0
# Diving into HTML and the Tools of the Trade                                                            3.5
# Google Maps Styling in Flutter                                                                         0.0
# How I became a Frontend Developer                                                                      3.5
# How ServiceNow users can use AI and what AI search engines means for chatbots                          0.0
# How to integrate an API in Flutter                                                                     0.0
# How to not call everything just ‘AI’: A business communication cheat sheet                             0.0
# Learning Too Many Programming Languages at Once?                                                       5.0
# Open screen in the background in a flutter                                                             0.0
# Realtime Object detection using TensorFlow in Angular                                                  0.0
# The 2023 Backend Developer and Roadmap                                                                 0.0
# Writing an Algorithm to Calculate Article Read Length                                                  5.0
#
# user                                                                                                  12    \
# title
# 2 ChatGPT (Free) Chrome Extensions so Useful They Almost Feel Illegal                                  3.5
# 51 Far Better Things to Do than Scrolling Through Your Smartphone                                      0.0
# Animated Icons: Bottom Nav in Flutter & Rive                                                           2.0
# April 1st Recommendation on Alignment                                                                  3.5
# Background Services in Flutter Add-to-App Case                                                         2.0
# Calling in the background in a flutter                                                                 0.0
# Chat-GPT: 5 Game-Changing Functions in AI, Content, Translation, Classification, and Personalization   2.0
# Conflux Network: A High-Throughput Proof-of-Work Blockchain                                            0.0
# Cryptocurrency Regulations: A Tug of War Between Investors and Bureaucrats                             0.0
# Diving into HTML and the Tools of the Trade                                                            0.0
# Google Maps Styling in Flutter                                                                         0.0
# How I became a Frontend Developer                                                                      0.0
# How ServiceNow users can use AI and what AI search engines means for chatbots                          5.0
# How to integrate an API in Flutter                                                                     0.0
# How to not call everything just ‘AI’: A business communication cheat sheet                             0.0
# Learning Too Many Programming Languages at Once?                                                       0.0
# Open screen in the background in a flutter                                                             0.0
# Realtime Object detection using TensorFlow in Angular                                                  5.0
# The 2023 Backend Developer and Roadmap                                                                 0.0
# Writing an Algorithm to Calculate Article Read Length                                                  0.0
#
# user                                                                                                  14    \
# title
# 2 ChatGPT (Free) Chrome Extensions so Useful They Almost Feel Illegal                                  0.0
# 51 Far Better Things to Do than Scrolling Through Your Smartphone                                      0.0
# Animated Icons: Bottom Nav in Flutter & Rive                                                           0.0
# April 1st Recommendation on Alignment                                                                  0.0
# Background Services in Flutter Add-to-App Case                                                         0.0
# Calling in the background in a flutter                                                                 0.0
# Chat-GPT: 5 Game-Changing Functions in AI, Content, Translation, Classification, and Personalization   0.0
# Conflux Network: A High-Throughput Proof-of-Work Blockchain                                            0.0
# Cryptocurrency Regulations: A Tug of War Between Investors and Bureaucrats                             0.0
# Diving into HTML and the Tools of the Trade                                                            0.0
# Google Maps Styling in Flutter                                                                         0.0
# How I became a Frontend Developer                                                                      0.0
# How ServiceNow users can use AI and what AI search engines means for chatbots                          0.0
# How to integrate an API in Flutter                                                                     0.0
# How to not call everything just ‘AI’: A business communication cheat sheet                             0.0
# Learning Too Many Programming Languages at Once?                                                       0.0
# Open screen in the background in a flutter                                                             0.0
# Realtime Object detection using TensorFlow in Angular                                                  0.0
# The 2023 Backend Developer and Roadmap                                                                 0.0
# Writing an Algorithm to Calculate Article Read Length                                                  3.5
#
# user                                                                                                  23    \
# title
# 2 ChatGPT (Free) Chrome Extensions so Useful They Almost Feel Illegal                                  0.0
# 51 Far Better Things to Do than Scrolling Through Your Smartphone                                      0.0
# Animated Icons: Bottom Nav in Flutter & Rive                                                           0.0
# April 1st Recommendation on Alignment                                                                  0.0
# Background Services in Flutter Add-to-App Case                                                         0.0
# Calling in the background in a flutter                                                                 0.0
# Chat-GPT: 5 Game-Changing Functions in AI, Content, Translation, Classification, and Personalization   0.0
# Conflux Network: A High-Throughput Proof-of-Work Blockchain                                            0.0
# Cryptocurrency Regulations: A Tug of War Between Investors and Bureaucrats                             0.0
# Diving into HTML and the Tools of the Trade                                                            0.0
# Google Maps Styling in Flutter                                                                         0.0
# How I became a Frontend Developer                                                                      0.0
# How ServiceNow users can use AI and what AI search engines means for chatbots                          0.0
# How to integrate an API in Flutter                                                                     0.0
# How to not call everything just ‘AI’: A business communication cheat sheet                             0.0
# Learning Too Many Programming Languages at Once?                                                       0.0
# Open screen in the background in a flutter                                                             0.0
# Realtime Object detection using TensorFlow in Angular                                                  0.0
# The 2023 Backend Developer and Roadmap                                                                 0.0
# Writing an Algorithm to Calculate Article Read Length                                                  0.0
#
# user                                                                                                  29    \
# title
# 2 ChatGPT (Free) Chrome Extensions so Useful They Almost Feel Illegal                                  5.0
# 51 Far Better Things to Do than Scrolling Through Your Smartphone                                      0.0
# Animated Icons: Bottom Nav in Flutter & Rive                                                           0.0
# April 1st Recommendation on Alignment                                                                  0.0
# Background Services in Flutter Add-to-App Case                                                         0.0
# Calling in the background in a flutter                                                                 0.0
# Chat-GPT: 5 Game-Changing Functions in AI, Content, Translation, Classification, and Personalization   0.0
# Conflux Network: A High-Throughput Proof-of-Work Blockchain                                            0.0
# Cryptocurrency Regulations: A Tug of War Between Investors and Bureaucrats                             0.0
# Diving into HTML and the Tools of the Trade                                                            0.0
# Google Maps Styling in Flutter                                                                         0.0
# How I became a Frontend Developer                                                                      0.0
# How ServiceNow users can use AI and what AI search engines means for chatbots                          0.0
# How to integrate an API in Flutter                                                                     0.0
# How to not call everything just ‘AI’: A business communication cheat sheet                             0.0
# Learning Too Many Programming Languages at Once?                                                       0.0
# Open screen in the background in a flutter                                                             0.0
# Realtime Object detection using TensorFlow in Angular                                                  0.0
# The 2023 Backend Developer and Roadmap                                                                 0.0
# Writing an Algorithm to Calculate Article Read Length                                                  0.0
#
# user                                                                                                  37    \
# title
# 2 ChatGPT (Free) Chrome Extensions so Useful They Almost Feel Illegal                                  0.0
# 51 Far Better Things to Do than Scrolling Through Your Smartphone                                      0.0
# Animated Icons: Bottom Nav in Flutter & Rive                                                           0.0
# April 1st Recommendation on Alignment                                                                  0.0
# Background Services in Flutter Add-to-App Case                                                         2.0
# Calling in the background in a flutter                                                                 0.0
# Chat-GPT: 5 Game-Changing Functions in AI, Content, Translation, Classification, and Personalization   0.0
# Conflux Network: A High-Throughput Proof-of-Work Blockchain                                            0.0
# Cryptocurrency Regulations: A Tug of War Between Investors and Bureaucrats                             0.0
# Diving into HTML and the Tools of the Trade                                                            0.0
# Google Maps Styling in Flutter                                                                         0.0
# How I became a Frontend Developer                                                                      0.0
# How ServiceNow users can use AI and what AI search engines means for chatbots                          0.0
# How to integrate an API in Flutter                                                                     0.0
# How to not call everything just ‘AI’: A business communication cheat sheet                             0.0
# Learning Too Many Programming Languages at Once?                                                       0.0
# Open screen in the background in a flutter                                                             5.0
# Realtime Object detection using TensorFlow in Angular                                                  0.0
# The 2023 Backend Developer and Roadmap                                                                 0.0
# Writing an Algorithm to Calculate Article Read Length                                                  0.0
#
# user                                                                                                  38    \
# title
# 2 ChatGPT (Free) Chrome Extensions so Useful They Almost Feel Illegal                                  0.0
# 51 Far Better Things to Do than Scrolling Through Your Smartphone                                      0.0
# Animated Icons: Bottom Nav in Flutter & Rive                                                           0.0
# April 1st Recommendation on Alignment                                                                  0.0
# Background Services in Flutter Add-to-App Case                                                         0.0
# Calling in the background in a flutter                                                                 0.0
# Chat-GPT: 5 Game-Changing Functions in AI, Content, Translation, Classification, and Personalization   0.0
# Conflux Network: A High-Throughput Proof-of-Work Blockchain                                            0.0
# Cryptocurrency Regulations: A Tug of War Between Investors and Bureaucrats                             0.0
# Diving into HTML and the Tools of the Trade                                                            0.0
# Google Maps Styling in Flutter                                                                         0.0
# How I became a Frontend Developer                                                                      3.5
# How ServiceNow users can use AI and what AI search engines means for chatbots                          0.0
# How to integrate an API in Flutter                                                                     0.0
# How to not call everything just ‘AI’: A business communication cheat sheet                             0.0
# Learning Too Many Programming Languages at Once?                                                       0.0
# Open screen in the background in a flutter                                                             0.0
# Realtime Object detection using TensorFlow in Angular                                                  0.0
# The 2023 Backend Developer and Roadmap                                                                 0.0
# Writing an Algorithm to Calculate Article Read Length                                                  0.0
#
# user                                                                                                  53    \
# title
# 2 ChatGPT (Free) Chrome Extensions so Useful They Almost Feel Illegal                                  0.0
# 51 Far Better Things to Do than Scrolling Through Your Smartphone                                      0.0
# Animated Icons: Bottom Nav in Flutter & Rive                                                           0.0
# April 1st Recommendation on Alignment                                                                  0.0
# Background Services in Flutter Add-to-App Case                                                         0.0
# Calling in the background in a flutter                                                                 3.5
# Chat-GPT: 5 Game-Changing Functions in AI, Content, Translation, Classification, and Personalization   0.0
# Conflux Network: A High-Throughput Proof-of-Work Blockchain                                            0.0
# Cryptocurrency Regulations: A Tug of War Between Investors and Bureaucrats                             0.0
# Diving into HTML and the Tools of the Trade                                                            0.0
# Google Maps Styling in Flutter                                                                         0.0
# How I became a Frontend Developer                                                                      0.0
# How ServiceNow users can use AI and what AI search engines means for chatbots                          0.0
# How to integrate an API in Flutter                                                                     0.0
# How to not call everything just ‘AI’: A business communication cheat sheet                             0.0
# Learning Too Many Programming Languages at Once?                                                       0.0
# Open screen in the background in a flutter                                                             0.0
# Realtime Object detection using TensorFlow in Angular                                                  0.0
# The 2023 Backend Developer and Roadmap                                                                 0.0
# Writing an Algorithm to Calculate Article Read Length                                                  0.0
#
# user                                                                                                  54    \
# title
# 2 ChatGPT (Free) Chrome Extensions so Useful They Almost Feel Illegal                                  0.0
# 51 Far Better Things to Do than Scrolling Through Your Smartphone                                      0.0
# Animated Icons: Bottom Nav in Flutter & Rive                                                           0.0
# April 1st Recommendation on Alignment                                                                  0.0
# Background Services in Flutter Add-to-App Case                                                         0.0
# Calling in the background in a flutter                                                                 0.0
# Chat-GPT: 5 Game-Changing Functions in AI, Content, Translation, Classification, and Personalization   0.0
# Conflux Network: A High-Throughput Proof-of-Work Blockchain                                            0.0
# Cryptocurrency Regulations: A Tug of War Between Investors and Bureaucrats                             0.0
# Diving into HTML and the Tools of the Trade                                                            0.0
# Google Maps Styling in Flutter                                                                         0.0
# How I became a Frontend Developer                                                                      0.0
# How ServiceNow users can use AI and what AI search engines means for chatbots                          0.0
# How to integrate an API in Flutter                                                                     0.0
# How to not call everything just ‘AI’: A business communication cheat sheet                             0.0
# Learning Too Many Programming Languages at Once?                                                       0.0
# Open screen in the background in a flutter                                                             0.0
# Realtime Object detection using TensorFlow in Angular                                                  0.0
# The 2023 Backend Developer and Roadmap                                                                 0.0
# Writing an Algorithm to Calculate Article Read Length                                                  0.0
#
# user                                                                                                  57    \
# title
# 2 ChatGPT (Free) Chrome Extensions so Useful They Almost Feel Illegal                                  0.0
# 51 Far Better Things to Do than Scrolling Through Your Smartphone                                      0.0
# Animated Icons: Bottom Nav in Flutter & Rive                                                           0.0
# April 1st Recommendation on Alignment                                                                  0.0
# Background Services in Flutter Add-to-App Case                                                         0.0
# Calling in the background in a flutter                                                                 0.0
# Chat-GPT: 5 Game-Changing Functions in AI, Content, Translation, Classification, and Personalization   0.0
# Conflux Network: A High-Throughput Proof-of-Work Blockchain                                            5.0
# Cryptocurrency Regulations: A Tug of War Between Investors and Bureaucrats                             0.0
# Diving into HTML and the Tools of the Trade                                                            0.0
# Google Maps Styling in Flutter                                                                         0.0
# How I became a Frontend Developer                                                                      0.0
# How ServiceNow users can use AI and what AI search engines means for chatbots                          0.0
# How to integrate an API in Flutter                                                                     0.0
# How to not call everything just ‘AI’: A business communication cheat sheet                             0.0
# Learning Too Many Programming Languages at Once?                                                       0.0
# Open screen in the background in a flutter                                                             0.0
# Realtime Object detection using TensorFlow in Angular                                                  0.0
# The 2023 Backend Developer and Roadmap                                                                 0.0
# Writing an Algorithm to Calculate Article Read Length                                                  0.0
#
# user                                                                                                  ...  \
# title                                                                                                 ...
# 2 ChatGPT (Free) Chrome Extensions so Useful They Almost Feel Illegal                                 ...
# 51 Far Better Things to Do than Scrolling Through Your Smartphone                                     ...
# Animated Icons: Bottom Nav in Flutter & Rive                                                          ...
# April 1st Recommendation on Alignment                                                                 ...
# Background Services in Flutter Add-to-App Case                                                        ...
# Calling in the background in a flutter                                                                ...
# Chat-GPT: 5 Game-Changing Functions in AI, Content, Translation, Classification, and Personalization  ...
# Conflux Network: A High-Throughput Proof-of-Work Blockchain                                           ...
# Cryptocurrency Regulations: A Tug of War Between Investors and Bureaucrats                            ...
# Diving into HTML and the Tools of the Trade                                                           ...
# Google Maps Styling in Flutter                                                                        ...
# How I became a Frontend Developer                                                                     ...
# How ServiceNow users can use AI and what AI search engines means for chatbots                         ...
# How to integrate an API in Flutter                                                                    ...
# How to not call everything just ‘AI’: A business communication cheat sheet                            ...
# Learning Too Many Programming Languages at Once?                                                      ...
# Open screen in the background in a flutter                                                            ...
# Realtime Object detection using TensorFlow in Angular                                                 ...
# The 2023 Backend Developer and Roadmap                                                                ...
# Writing an Algorithm to Calculate Article Read Length                                                 ...
#
# user                                                                                                  4901  \
# title
# 2 ChatGPT (Free) Chrome Extensions so Useful They Almost Feel Illegal                                  0.0
# 51 Far Better Things to Do than Scrolling Through Your Smartphone                                      0.0
# Animated Icons: Bottom Nav in Flutter & Rive                                                           0.0
# April 1st Recommendation on Alignment                                                                  0.0
# Background Services in Flutter Add-to-App Case                                                         0.0
# Calling in the background in a flutter                                                                 0.0
# Chat-GPT: 5 Game-Changing Functions in AI, Content, Translation, Classification, and Personalization   0.0
# Conflux Network: A High-Throughput Proof-of-Work Blockchain                                            0.0
# Cryptocurrency Regulations: A Tug of War Between Investors and Bureaucrats                             0.0
# Diving into HTML and the Tools of the Trade                                                            0.0
# Google Maps Styling in Flutter                                                                         0.0
# How I became a Frontend Developer                                                                      2.0
# How ServiceNow users can use AI and what AI search engines means for chatbots                          0.0
# How to integrate an API in Flutter                                                                     0.0
# How to not call everything just ‘AI’: A business communication cheat sheet                             0.0
# Learning Too Many Programming Languages at Once?                                                       0.0
# Open screen in the background in a flutter                                                             0.0
# Realtime Object detection using TensorFlow in Angular                                                  0.0
# The 2023 Backend Developer and Roadmap                                                                 0.0
# Writing an Algorithm to Calculate Article Read Length                                                  0.0
#
# user                                                                                                  4906  \
# title
# 2 ChatGPT (Free) Chrome Extensions so Useful They Almost Feel Illegal                                  0.0
# 51 Far Better Things to Do than Scrolling Through Your Smartphone                                      0.0
# Animated Icons: Bottom Nav in Flutter & Rive                                                           0.0
# April 1st Recommendation on Alignment                                                                  0.0
# Background Services in Flutter Add-to-App Case                                                         0.0
# Calling in the background in a flutter                                                                 0.0
# Chat-GPT: 5 Game-Changing Functions in AI, Content, Translation, Classification, and Personalization   0.0
# Conflux Network: A High-Throughput Proof-of-Work Blockchain                                            0.0
# Cryptocurrency Regulations: A Tug of War Between Investors and Bureaucrats                             0.0
# Diving into HTML and the Tools of the Trade                                                            0.0
# Google Maps Styling in Flutter                                                                         0.0
# How I became a Frontend Developer                                                                      5.0
# How ServiceNow users can use AI and what AI search engines means for chatbots                          0.0
# How to integrate an API in Flutter                                                                     0.0
# How to not call everything just ‘AI’: A business communication cheat sheet                             0.0
# Learning Too Many Programming Languages at Once?                                                       0.0
# Open screen in the background in a flutter                                                             0.0
# Realtime Object detection using TensorFlow in Angular                                                  0.0
# The 2023 Backend Developer and Roadmap                                                                 0.0
# Writing an Algorithm to Calculate Article Read Length                                                  0.0
#
# user                                                                                                  4907  \
# title
# 2 ChatGPT (Free) Chrome Extensions so Useful They Almost Feel Illegal                                  0.0
# 51 Far Better Things to Do than Scrolling Through Your Smartphone                                      0.0
# Animated Icons: Bottom Nav in Flutter & Rive                                                           0.0
# April 1st Recommendation on Alignment                                                                  0.0
# Background Services in Flutter Add-to-App Case                                                         0.0
# Calling in the background in a flutter                                                                 0.0
# Chat-GPT: 5 Game-Changing Functions in AI, Content, Translation, Classification, and Personalization   0.0
# Conflux Network: A High-Throughput Proof-of-Work Blockchain                                            0.0
# Cryptocurrency Regulations: A Tug of War Between Investors and Bureaucrats                             0.0
# Diving into HTML and the Tools of the Trade                                                            0.0
# Google Maps Styling in Flutter                                                                         0.0
# How I became a Frontend Developer                                                                      0.0
# How ServiceNow users can use AI and what AI search engines means for chatbots                          2.0
# How to integrate an API in Flutter                                                                     0.0
# How to not call everything just ‘AI’: A business communication cheat sheet                             0.0
# Learning Too Many Programming Languages at Once?                                                       0.0
# Open screen in the background in a flutter                                                             0.0
# Realtime Object detection using TensorFlow in Angular                                                  0.0
# The 2023 Backend Developer and Roadmap                                                                 0.0
# Writing an Algorithm to Calculate Article Read Length                                                  0.0
#
# user                                                                                                  4908  \
# title
# 2 ChatGPT (Free) Chrome Extensions so Useful They Almost Feel Illegal                                  0.0
# 51 Far Better Things to Do than Scrolling Through Your Smartphone                                      0.0
# Animated Icons: Bottom Nav in Flutter & Rive                                                           0.0
# April 1st Recommendation on Alignment                                                                  0.0
# Background Services in Flutter Add-to-App Case                                                         0.0
# Calling in the background in a flutter                                                                 0.0
# Chat-GPT: 5 Game-Changing Functions in AI, Content, Translation, Classification, and Personalization   0.0
# Conflux Network: A High-Throughput Proof-of-Work Blockchain                                            0.0
# Cryptocurrency Regulations: A Tug of War Between Investors and Bureaucrats                             0.0
# Diving into HTML and the Tools of the Trade                                                            0.0
# Google Maps Styling in Flutter                                                                         5.0
# How I became a Frontend Developer                                                                      0.0
# How ServiceNow users can use AI and what AI search engines means for chatbots                          0.0
# How to integrate an API in Flutter                                                                     0.0
# How to not call everything just ‘AI’: A business communication cheat sheet                             0.0
# Learning Too Many Programming Languages at Once?                                                       0.0
# Open screen in the background in a flutter                                                             0.0
# Realtime Object detection using TensorFlow in Angular                                                  0.0
# The 2023 Backend Developer and Roadmap                                                                 0.0
# Writing an Algorithm to Calculate Article Read Length                                                  0.0
#
# user                                                                                                  4940  \
# title
# 2 ChatGPT (Free) Chrome Extensions so Useful They Almost Feel Illegal                                  0.0
# 51 Far Better Things to Do than Scrolling Through Your Smartphone                                      0.0
# Animated Icons: Bottom Nav in Flutter & Rive                                                           0.0
# April 1st Recommendation on Alignment                                                                  0.0
# Background Services in Flutter Add-to-App Case                                                         0.0
# Calling in the background in a flutter                                                                 0.0
# Chat-GPT: 5 Game-Changing Functions in AI, Content, Translation, Classification, and Personalization   0.0
# Conflux Network: A High-Throughput Proof-of-Work Blockchain                                            0.0
# Cryptocurrency Regulations: A Tug of War Between Investors and Bureaucrats                             0.0
# Diving into HTML and the Tools of the Trade                                                            0.0
# Google Maps Styling in Flutter                                                                         0.0
# How I became a Frontend Developer                                                                      5.0
# How ServiceNow users can use AI and what AI search engines means for chatbots                          0.0
# How to integrate an API in Flutter                                                                     0.0
# How to not call everything just ‘AI’: A business communication cheat sheet                             0.0
# Learning Too Many Programming Languages at Once?                                                       0.0
# Open screen in the background in a flutter                                                             0.0
# Realtime Object detection using TensorFlow in Angular                                                  0.0
# The 2023 Backend Developer and Roadmap                                                                 0.0
# Writing an Algorithm to Calculate Article Read Length                                                  0.0
#
# user                                                                                                  4963  \
# title
# 2 ChatGPT (Free) Chrome Extensions so Useful They Almost Feel Illegal                                  0.0
# 51 Far Better Things to Do than Scrolling Through Your Smartphone                                      0.0
# Animated Icons: Bottom Nav in Flutter & Rive                                                           5.0
# April 1st Recommendation on Alignment                                                                  0.0
# Background Services in Flutter Add-to-App Case                                                         0.0
# Calling in the background in a flutter                                                                 0.0
# Chat-GPT: 5 Game-Changing Functions in AI, Content, Translation, Classification, and Personalization   0.0
# Conflux Network: A High-Throughput Proof-of-Work Blockchain                                            0.0
# Cryptocurrency Regulations: A Tug of War Between Investors and Bureaucrats                             0.0
# Diving into HTML and the Tools of the Trade                                                            0.0
# Google Maps Styling in Flutter                                                                         0.0
# How I became a Frontend Developer                                                                      0.0
# How ServiceNow users can use AI and what AI search engines means for chatbots                          0.0
# How to integrate an API in Flutter                                                                     0.0
# How to not call everything just ‘AI’: A business communication cheat sheet                             0.0
# Learning Too Many Programming Languages at Once?                                                       0.0
# Open screen in the background in a flutter                                                             0.0
# Realtime Object detection using TensorFlow in Angular                                                  0.0
# The 2023 Backend Developer and Roadmap                                                                 0.0
# Writing an Algorithm to Calculate Article Read Length                                                  0.0
#
# user                                                                                                  4966  \
# title
# 2 ChatGPT (Free) Chrome Extensions so Useful They Almost Feel Illegal                                  0.0
# 51 Far Better Things to Do than Scrolling Through Your Smartphone                                      0.0
# Animated Icons: Bottom Nav in Flutter & Rive                                                           0.0
# April 1st Recommendation on Alignment                                                                  0.0
# Background Services in Flutter Add-to-App Case                                                         0.0
# Calling in the background in a flutter                                                                 5.0
# Chat-GPT: 5 Game-Changing Functions in AI, Content, Translation, Classification, and Personalization   0.0
# Conflux Network: A High-Throughput Proof-of-Work Blockchain                                            0.0
# Cryptocurrency Regulations: A Tug of War Between Investors and Bureaucrats                             0.0
# Diving into HTML and the Tools of the Trade                                                            0.0
# Google Maps Styling in Flutter                                                                         0.0
# How I became a Frontend Developer                                                                      0.0
# How ServiceNow users can use AI and what AI search engines means for chatbots                          0.0
# How to integrate an API in Flutter                                                                     0.0
# How to not call everything just ‘AI’: A business communication cheat sheet                             0.0
# Learning Too Many Programming Languages at Once?                                                       0.0
# Open screen in the background in a flutter                                                             0.0
# Realtime Object detection using TensorFlow in Angular                                                  0.0
# The 2023 Backend Developer and Roadmap                                                                 0.0
# Writing an Algorithm to Calculate Article Read Length                                                  0.0
#
# user                                                                                                  4971  \
# title
# 2 ChatGPT (Free) Chrome Extensions so Useful They Almost Feel Illegal                                  0.0
# 51 Far Better Things to Do than Scrolling Through Your Smartphone                                      0.0
# Animated Icons: Bottom Nav in Flutter & Rive                                                           0.0
# April 1st Recommendation on Alignment                                                                  0.0
# Background Services in Flutter Add-to-App Case                                                         0.0
# Calling in the background in a flutter                                                                 0.0
# Chat-GPT: 5 Game-Changing Functions in AI, Content, Translation, Classification, and Personalization   0.0
# Conflux Network: A High-Throughput Proof-of-Work Blockchain                                            0.0
# Cryptocurrency Regulations: A Tug of War Between Investors and Bureaucrats                             0.0
# Diving into HTML and the Tools of the Trade                                                            0.0
# Google Maps Styling in Flutter                                                                         0.0
# How I became a Frontend Developer                                                                      5.0
# How ServiceNow users can use AI and what AI search engines means for chatbots                          0.0
# How to integrate an API in Flutter                                                                     0.0
# How to not call everything just ‘AI’: A business communication cheat sheet                             0.0
# Learning Too Many Programming Languages at Once?                                                       5.0
# Open screen in the background in a flutter                                                             0.0
# Realtime Object detection using TensorFlow in Angular                                                  0.0
# The 2023 Backend Developer and Roadmap                                                                 0.0
# Writing an Algorithm to Calculate Article Read Length                                                  2.0
#
# user                                                                                                  4983  \
# title
# 2 ChatGPT (Free) Chrome Extensions so Useful They Almost Feel Illegal                                  0.0
# 51 Far Better Things to Do than Scrolling Through Your Smartphone                                      0.0
# Animated Icons: Bottom Nav in Flutter & Rive                                                           0.0
# April 1st Recommendation on Alignment                                                                  0.0
# Background Services in Flutter Add-to-App Case                                                         0.0
# Calling in the background in a flutter                                                                 0.0
# Chat-GPT: 5 Game-Changing Functions in AI, Content, Translation, Classification, and Personalization   0.0
# Conflux Network: A High-Throughput Proof-of-Work Blockchain                                            0.0
# Cryptocurrency Regulations: A Tug of War Between Investors and Bureaucrats                             0.0
# Diving into HTML and the Tools of the Trade                                                            0.0
# Google Maps Styling in Flutter                                                                         0.0
# How I became a Frontend Developer                                                                      0.0
# How ServiceNow users can use AI and what AI search engines means for chatbots                          0.0
# How to integrate an API in Flutter                                                                     0.0
# How to not call everything just ‘AI’: A business communication cheat sheet                             0.0
# Learning Too Many Programming Languages at Once?                                                       0.0
# Open screen in the background in a flutter                                                             0.0
# Realtime Object detection using TensorFlow in Angular                                                  0.0
# The 2023 Backend Developer and Roadmap                                                                 0.0
# Writing an Algorithm to Calculate Article Read Length                                                  0.0
#
# user                                                                                                  4994
# title
# 2 ChatGPT (Free) Chrome Extensions so Useful They Almost Feel Illegal                                  0.0
# 51 Far Better Things to Do than Scrolling Through Your Smartphone                                      0.0
# Animated Icons: Bottom Nav in Flutter & Rive                                                           0.0
# April 1st Recommendation on Alignment                                                                  0.0
# Background Services in Flutter Add-to-App Case                                                         0.0
# Calling in the background in a flutter                                                                 0.0
# Chat-GPT: 5 Game-Changing Functions in AI, Content, Translation, Classification, and Personalization   0.0
# Conflux Network: A High-Throughput Proof-of-Work Blockchain                                            0.0
# Cryptocurrency Regulations: A Tug of War Between Investors and Bureaucrats                             0.0
# Diving into HTML and the Tools of the Trade                                                            0.0
# Google Maps Styling in Flutter                                                                         5.0
# How I became a Frontend Developer                                                                      0.0
# How ServiceNow users can use AI and what AI search engines means for chatbots                          0.0
# How to integrate an API in Flutter                                                                     0.0
# How to not call everything just ‘AI’: A business communication cheat sheet                             0.0
# Learning Too Many Programming Languages at Once?                                                       0.0
# Open screen in the background in a flutter                                                             0.0
# Realtime Object detection using TensorFlow in Angular                                                  0.0
# The 2023 Backend Developer and Roadmap                                                                 0.0
# Writing an Algorithm to Calculate Article Read Length                                                  0.0
#
# [20 rows x 383 columns]

# %% [markdown]
# Se observa que em alguns casos, alguns blogs poucas pessoas leram, mas isso acontece por que alguns se tratam de conteúdos bem específicos se somente alguns usuários teriam interesse em ler.

# %% [markdown]
# ### Agrupamento final
# Agora com os dados todos organizados, é necessário definir como vai encará-los, com isso, usando a definição dele mesmo como as mudanças, foi definido o seguinte sobre eles:
# * 0 - Não leu o blog. (Mesmo que tenha lido, não deu nota, então é como se não tivesse lido)
# * 2 - Se o usuário gostou do blog
# * 3 - Se o usuário adicionou o blog aos favoritos
# * 5 - Se o usuário gostou e adicionou o blog para favoritos
#
# Vai ser deixado somente números inteiros para facilitar a vida do modelo, esse processo pode ser observado na célula 14.

# %%
blogs['rating'] = blogs['rating'].astype('int')

# %% [markdown]
# ## Fatores Latentes
# Fatores Latentes são variáveis que não são observadas diretamente nos dados apresentados, mas elas podem ser inferidas indiretamente a partir das variáveis que são observadas. O objetivo é justamente encontrar esses Fatores Latentes tanto para os usuários quanto para os blogs, e através dele se realizar as predições de quais blogs um usuário específico gostaria ou não de ler.
#
# Esses fatores primeiro serão gerados aleatoriamente e serão atualizados conforme o modelo é treinado, sendo usado para isso o gradiente.

# %% [markdown]
# ## Vies
# Outra coisa importante a se considerar é o Vies, pois alguns usuários podem ter a tendência de dar notas mais positivas e outros mais negativas, como também alguns blogs podem tender e receber notas mais positivas e outros mais negativas, então o modelo deve considerar esses aspectos.

# %% [markdown]
# ## Modelos
# Para se começar, o primeiro passo é usar a biblioteca da fastai para poder criar os DataLoaders, usados para carregar os dados de uma forma que possa ser usado para treinar o modelo, esse primeiro processo pode ser observado na célula 15.

# %%
dls = CollabDataLoaders.from_df(blogs, item_name='title', bs=64)
dls.show_batch()
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>user</th>
#       <th>title</th>
#       <th>rating</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2120</td>
#       <td>Protecting Sensitive Data in Python Logging: A Guide to Redacting Information</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>4965</td>
#       <td>Cryptography — Sign payload, Encrypt a plain text password and Decrypt it</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2608</td>
#       <td>Blade Labs Launches Suite of White Label Wallet Products for Android, iOS and Unreal Engine to Accelerate Web3 Adoption by Enterprises</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>3895</td>
#       <td>Ocean Protocol Update || 2023</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>1276</td>
#       <td>Understanding Keras RNN API</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>3429</td>
#       <td>Web Stack Weekly — Issue#62</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>2652</td>
#       <td>How to Use Default Parameters in Java Methods</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>721</td>
#       <td>The LazyLoad | Flutter-Firebase</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>4191</td>
#       <td>Level Up Your Skills with This Beginner Prompt Engineering Guide</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>4797</td>
#       <td>How AI is changing customer service for the better!</td>
#       <td>5</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Para uma primeira tentativa de modelo, será feito uma função que leva em conta o fator de vies e ver como esse modelo se sai, isso pode ser observado na célula 16, com o primeiro passo de se pegar a quantidade de valores de usuários e blogs.

# %%
n_users  = len(dls.classes['user'])
n_blogs = len(dls.classes['title'])

# %% [markdown]
# Agora se tendo essa informação, pode-se criar a função para ser usada na criação do modelo, isso pode ser observa na célula 17.

# %%
class DotProductBias(Module):
    def __init__(self, n_users, n_blogs, n_factors, y_range=(0,5.5)):
        self.user_factors = Embedding(n_users, n_factors)
        self.user_bias = Embedding(n_users, 1)
        self.blog_factors = Embedding(n_blogs, n_factors)
        self.blog_bias = Embedding(n_blogs, 1)
        self.y_range = y_range
        
    def forward(self, x):
        users = self.user_factors(x[:,0])
        bloog = self.blog_factors(x[:,1])
        res = (users * bloog).sum(dim=1, keepdim=True)
        res += self.user_bias(x[:,0]) + self.blog_bias(x[:,1])
        return sigmoid_range(res, *self.y_range)

# %% [markdown]
# Agora com a função criada, pode-se criar de fato o modelo e treiná-lo, esse processo pode ser observado na célula 18.

# %%
model = DotProductBias(n_users, n_blogs, 50)
learn = Learner(dls, model, loss_func=MSELossFlat())
learn.fit_one_cycle(5, 11e-3)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>3.767183</td>
#       <td>3.882106</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>3.686265</td>
#       <td>4.778177</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.543564</td>
#       <td>5.071566</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.634431</td>
#       <td>5.019003</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.235700</td>
#       <td>5.011824</td>
#       <td>00:20</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# É possível notar um problema, o modelo diminui o loss de treinamento, mas não o de validação, isso acontece por que ele está apenas decorando os dados de treinamento, para isso é necessário usar a Decadência de peso.

# %% [markdown]
# ### Decadência de Peso
# O que se deseja fazer é penalizar pesos muito altos, para não ocorrer o sobreajuste, e de posse dessa informação, o modelo será treinado novamente, observável na célula 19.

# %%
model = DotProductBias(n_users, n_blogs, 50)
learn_c = Learner(dls, model, loss_func=MSELossFlat())
learn_c.fit_one_cycle(5, 11e-3, wd=0.1)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>3.788451</td>
#       <td>3.766351</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>3.781252</td>
#       <td>3.799533</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>3.554136</td>
#       <td>3.775183</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>3.104404</td>
#       <td>3.779299</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>2.285101</td>
#       <td>3.793869</td>
#       <td>00:21</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# É possível notar que ele ainda sofre de sobreajuste, mas o resultado obtido é melhor do que o primeiro modelo.

# %% [markdown]
# ## Interpretando os dados
# Depois do teste de vários modelos, é interessante observar os resultados, mostrando primeiro quais os blogs estão no topo de cada vies, ou seja, aqueles mais propensos a notas positivas e aqueles mais propensos a notas negativas, isso pode ser observado nas células 20 e 21.

# %%
blogs_bias = learn_c.model.blog_bias.weight.squeeze()
idxs = blogs_bias.argsort()[:5]
[dls.classes['title'][i] for i in idxs]
# Out:
# ['Outlier Detection Using Principal Component Analysis and Hotelling’s T2 and SPE/DmodX Methods',
#  '6 Takeaways from ETHDenver 2023',
#  'Power Up Your Data Visuals with Power BI',
#  'A quick guide to deploying your Python webapp on Google App Engine',
#  'Ensuring Security and Privacy in NLP Models like ChatGPT and Google BERT']

# %%
idxs = blogs_bias.argsort(descending=True)[:5]
[dls.classes['title'][i] for i in idxs]
# Out:
# ['Top Mobile App Development Trends To Look Out For In 2023',
#  'Read Image Using OpenCV Framework',
#  '03–14–2023 — Lif3 Update',
#  'Upload Your App to the Play Store: A Complete Beginner’s Walkthrough',
#  'Open-Source Contribution to NLP packages']

# %% [markdown]
# Com isso se pode visualizar aqueles que possuem um vies de receber notas mais altas e notas menores.

# %% [markdown]
# ## Aprendizado Profundo
# Para tentar melhorar o modelo, se passará para o método de aprendizado profundo, onde agora se tem a ideia de criação de camadas com esses valores latentes, e um dos primeiros passos que pode ser realizado é usar uma função do fastai que com base na sua heurística retorne uma quantidade boa de fatores latentes conforme as variáveis usadas, esse processo pode ser encontrado na célula 22.

# %%
embs = get_emb_sz(dls)
embs
# Out:
# [(4965, 188), (9706, 273)]

# %% [markdown]
# De posse desses valores, pode-se criar a função que fara a criação de um modelo em camadas, podendo ser observado na célula 23.

# %%
class CollabNN(Module):
    def __init__(self, user_sz, item_sz, y_range=(0,5.5), n_act=100):
        self.user_factors = Embedding(*user_sz)
        self.item_factors = Embedding(*item_sz)
        self.layers = nn.Sequential(
            nn.Linear(user_sz[1]+item_sz[1], n_act),
            nn.ReLU(),
            nn.Linear(n_act, 1))
        self.y_range = y_range
        
    def forward(self, x):
        embs = self.user_factors(x[:,0]),self.item_factors(x[:,1])
        x = self.layers(torch.cat(embs, dim=1))
        return sigmoid_range(x, *self.y_range)

# %% [markdown]
# Com tudo isso pode-se criar de fato o modelo e treiná-lo, esse processo pode ser observado na célula 24.

# %%
model = CollabNN(*embs)

learn = collab_learner(dls, use_nn=True, y_range=(0, 5.5), layers=[100, 50])
learn.fit_one_cycle(5, 11e-3, wd=0.1)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>3.625021</td>
#       <td>3.682752</td>
#       <td>00:27</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>3.689891</td>
#       <td>3.676275</td>
#       <td>00:25</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>3.641419</td>
#       <td>3.679555</td>
#       <td>00:25</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>3.652823</td>
#       <td>3.684319</td>
#       <td>00:25</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>3.538341</td>
#       <td>3.855625</td>
#       <td>00:25</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Embora tenha sofrido também com o sobreajuste, ainda se tornou melhor em comparação com os outros.

# %% [markdown]
# ## Exportando
# Para realizar a exportação, é preciso salvar o modelo e os dados de validação, pois serão com base neles que se deseja fazer as predições e as recomendações, esse processo pode ser observado na célula 25 e 26.

# %%
#Pegando os dados de validação
valid = dls.valid_ds
export = pd.DataFrame(valid.items)

#Exportando
export.to_csv('valid.csv', index=False)

# %%
learn.export('export.pkl')

# %% [markdown]
# O modelo em funcionamento pode ser encontrado em [Blogs](https://huggingface.co/spaces/fastaioncampus/Blogs)
